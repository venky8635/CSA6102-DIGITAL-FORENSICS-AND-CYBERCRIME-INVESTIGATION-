# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
header = input("Enter sender email: ")

if "@gmail.com" in header:
    print("Legitimate Sender")
else:
    print("Possible Spoofed Sender")
# Out:
# Enter sender email: hacker@fake.com
# Possible Spoofed Sender
