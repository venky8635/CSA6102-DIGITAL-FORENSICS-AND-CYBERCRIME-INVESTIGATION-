# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import time


file_name = "evidence.txt"

with open(file_name, "w") as file:
    file.write("Original Evidence")

print("File Created!")

time.sleep(3)

with open(file_name, "a") as file:
    file.write("\nModified by User")

print("File Modified!")

created_time = os.path.getctime(file_name)
modified_time = os.path.getmtime(file_name)

print("\n--- File Metadata ---")
print("Created Time :", time.ctime(created_time))
print("Modified Time:", time.ctime(modified_time))

if modified_time > created_time:
    print("\nLocard's Exchange Principle Demonstrated!")
    print("The file modification left a metadata trace.")
# Out:
# File Created!
# File Modified!
#
# --- File Metadata ---
# Created Time : Thu Jul 16 04:58:19 2026
# Modified Time: Thu Jul 16 04:58:19 2026
