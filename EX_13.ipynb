# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
case = input("Enter Case Name: ")
finding = input("Enter Investigation Finding: ")

print("\n----- DIGITAL FORENSIC REPORT -----")
print("Case Name :", case)
print("Finding   :", finding)
print("Status    : Investigation Completed")
print("Evidence  : Verified")
print("----------------------------------")
# Out:
# Enter Case Name: Phishing Case
# Enter Investigation Finding: Malicious email detected
#
# ----- DIGITAL FORENSIC REPORT -----
# Case Name : Phishing Case
# Finding   : Malicious email detected
# Status    : Investigation Completed
# Evidence  : Verified
# ----------------------------------
