# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import socket

domain = input("Enter domain name: ")

try:
    ip = socket.gethostbyname(domain)
    print("\nDNS Lookup Result")
    print("Domain :", domain)
    print("IP Address :", ip)
except socket.gaierror:
    print("Invalid domain or DNS lookup failed.")
# Out:
# Enter domain name: google.com
#
# DNS Lookup Result
# Domain : google.com
# IP Address : 142.251.189.139
