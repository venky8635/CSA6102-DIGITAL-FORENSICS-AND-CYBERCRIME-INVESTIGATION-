# %% [markdown]
# <a href="https://colab.research.google.com/github/venky8635/CSA6102-DIGITAL-FORENSICS-AND-CYBERCRIME-INVESTIGATION-/blob/main/EX_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
file_name = input("Enter file name: ")

try:
    with open(file_name, "rb") as file:
        header = file.read(4).hex().upper()

    if header.startswith("FFD8FF"):
        print("File Type: JPEG Image")
    elif header == "89504E47":
        print("File Type: PNG Image")
    elif header == "25504446":
        print("File Type: PDF Document")
    elif header == "504B0304":
        print("File Type: ZIP File")
    else:
        print("Unknown File Type")

except FileNotFoundError:
    print("File not found! Please enter a valid file name.")
# Out:
# Enter file name: sample.pdf
# File not found! Please enter a valid file name.
